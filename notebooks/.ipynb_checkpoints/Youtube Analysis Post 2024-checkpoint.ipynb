# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import pandas as pd
import time
import isodate
from langdetect import detect, LangDetectException  # pip install langdetect

API_KEY = "AIzaSyA15-WpNlkEbaRcvwoOq7QtiUYUSvUeHx8"
youtube = build("youtube", "v3", developerKey=API_KEY)

# -----------------------------
# Utilidad: ejecutar con retries
# -----------------------------
def execute_with_retries(request, max_retries=5, base_sleep=1.5):
    for i in range(max_retries):
        try:
            return request.execute()
        except HttpError as e:
            sleep_s = base_sleep * (2 ** i)
            print(f"HTTPError ({e.resp.status}). Reintentando en {sleep_s:.1f}s...")
            time.sleep(sleep_s)
    raise RuntimeError("Demasiados errores seguidos con la API (retries agotados).")

# -----------------------------
# NUEVO: Filtro de idioma inglés
# -----------------------------
def is_english(text, min_length=15):
    """
    Devuelve True si el texto está en inglés.
    - min_length: comentarios muy cortos ('lol', 'wow') se descartan
      porque langdetect no es fiable con textos tan breves.
    """
    if not text or len(text.strip()) < min_length:
        return False
    try:
        return detect(text) == "en"
    except LangDetectException:
        return False

# -----------------------------------------------
# 1) Buscar vídeos (solo IDs) por término y fecha
# -----------------------------------------------
def search_video_ids(query, max_results=20, published_after="2022-01-01T00:00:00Z", relevance_language="en"):
    video_ids = []
    request = youtube.search().list(
        part="id",
        q=query,
        type="video",
        order="relevance",
        maxResults=min(max_results, 50),
        publishedAfter=published_after,
        relevanceLanguage=relevance_language
    )
    response = execute_with_retries(request)
    for item in response.get("items", []):
        video_ids.append(item["id"]["videoId"])
    return list(dict.fromkeys(video_ids))

# ---------------------------------------------------------
# 2) Enriquecer vídeos: stats + duración + snippet (batch)
# ---------------------------------------------------------
def fetch_video_metadata(video_ids):
    rows = []
    for i in range(0, len(video_ids), 50):
        chunk = video_ids[i:i+50]
        request = youtube.videos().list(
            part="snippet,statistics,contentDetails",
            id=",".join(chunk)
        )
        response = execute_with_retries(request)

        for v in response.get("items", []):
            stats = v.get("statistics", {})
            cd = v.get("contentDetails", {})
            sn = v.get("snippet", {})

            duration_sec = None
            if "duration" in cd:
                try:
                    duration_sec = int(isodate.parse_duration(cd["duration"]).total_seconds())
                except Exception:
                    duration_sec = None

            rows.append({
                "video_id": v["id"],
                "title": sn.get("title"),
                "channel": sn.get("channelTitle"),
                "channel_id": sn.get("channelId"),
                "published_at": sn.get("publishedAt"),
                "description": sn.get("description"),
                "duration_sec": duration_sec,
                "viewCount": int(stats.get("viewCount", 0)) if stats.get("viewCount") else 0,
                "likeCount": int(stats.get("likeCount", 0)) if stats.get("likeCount") else 0,
                "commentCount": int(stats.get("commentCount", 0)) if stats.get("commentCount") else 0,
            })

    return pd.DataFrame(rows)

# -----------------------------------------------
# 3) Obtener comentarios top-level (paginando)
# -----------------------------------------------
def get_comments(video_id, max_comments=500, order="time"):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText",
        order=order
    )

    while request and len(comments) < max_comments:
        response = execute_with_retries(request)

        for item in response.get("items", []):
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            text = snippet.get("textDisplay", "")

            # FILTRO DE IDIOMA: descartar si no es inglés
            if not is_english(text):
                continue

            comments.append({
                "video_id": video_id,
                "comment_id": item["snippet"]["topLevelComment"]["id"],
                "text": text,
                "likes": snippet.get("likeCount", 0),
                "date": snippet.get("publishedAt"),
                "author": snippet.get("authorDisplayName"),
                "reply_count": item["snippet"].get("totalReplyCount", 0),
            })

            if len(comments) >= max_comments:
                break

        request = youtube.commentThreads().list_next(request, response)

    return comments

# -----------------------------------------------
# 4) Pipeline: buscar -> filtrar vídeos -> comentarios
# -----------------------------------------------
def collect_youtube_data(
    queries,
    max_videos_per_query=10,
    max_comments_per_video=300,
    published_after="2022-01-01T00:00:00Z",
    relevance_language="en",
    min_comment_count=200,
    min_duration_sec=180,
    comment_order="time"
):
    all_comments = []
    seen_comment_ids = set()
    seen_video_ids = set()

    for query in queries:
        print(f"\n Query: '{query}'")

        ids = search_video_ids(
            query=query,
            max_results=50,
            published_after=published_after,
            relevance_language=relevance_language
        )

        meta = fetch_video_metadata(ids)

        filtered = meta[
            (meta["commentCount"] >= min_comment_count) &
            (meta["duration_sec"].fillna(999999) >= min_duration_sec)
        ].copy()

        filtered = filtered.sort_values(["commentCount", "viewCount"], ascending=False)
        selected = filtered.head(max_videos_per_query)

        print(f" Vídeos seleccionados: {len(selected)} (de {len(meta)}) tras filtros")

        for _, v in selected.iterrows():
            vid = v["video_id"]
            if vid in seen_video_ids:
                continue
            seen_video_ids.add(vid)

            print(f" {v['title'][:70]} | comments={v['commentCount']} views={v['viewCount']}")

            try:
                comments = get_comments(vid, max_comments=max_comments_per_video, order=comment_order)
            except Exception as e:
                print(f"Error comentarios en {vid}: {e}")
                continue

            # Log de cuántos se filtraron por idioma
            print(f" Comentarios en inglés aceptados: {len(comments)}")

            for c in comments:
                cid = c.get("comment_id")
                if cid and cid in seen_comment_ids:
                    continue
                if cid:
                    seen_comment_ids.add(cid)

                c["video_title"] = v["title"]
                c["channel"] = v["channel"]
                c["published_at"] = v["published_at"]
                c["query_used"] = query
                c["video_viewCount"] = v["viewCount"]
                c["video_commentCount"] = v["commentCount"]
                c["video_duration_sec"] = v["duration_sec"]

                all_comments.append(c)

    return pd.DataFrame(all_comments)

# -------------------
# 5) Ejecutar
# -------------------
queries = [
    # General IA
    "artificial intelligence",
    "generative AI",
    "ChatGPT",
    "AI risks",
    "AI benefits",
    "AI ethics",
    "AI regulation",
    "AI bias",

    # Educación
    "AI in education",
    "ChatGPT students cheating",
    "ChatGPT learning tool",
    "AI replacing teachers",
    "ChatGPT homework students",
    "artificial intelligence school",
    "AI for learning",
    

    # Empleo
    "AI and jobs future",
    "AI taking jobs",
    "AI creating jobs",
    "new jobs artificial intelligence",
    "AI employment",
    "AI unemployment",
    "will AI take my job",
    "ChatGPT replace workers",
]

df = collect_youtube_data(
    queries=queries,
    max_videos_per_query=17,
    max_comments_per_video=300,
    published_after="2022-01-01T00:00:00Z",
    relevance_language="en",
    min_comment_count=200,
    min_duration_sec=180,
    comment_order="time"
)

df.to_csv("youtube_comments_AI.csv", index=False)
print(f"\n Total comentarios en inglés recogidos: {len(df)}")
df.head()
# Out:
#  Query: 'artificial intelligence'
#  Vídeos seleccionados: 10 (de 25) tras filtros
#  Godfather of AI WARNS: "You Have No Idea What's Coming" | comments=14931 views=5683925
#  Comentarios en inglés aceptados: 300
#  Artificial Intelligence | 60 Minutes Full Episodes | comments=8079 views=9276152
#  Comentarios en inglés aceptados: 300
#  AI2027: Is this how AI might destroy humanity? - BBC World Service | comments=5724 views=10954049
#  Comentarios en inglés aceptados: 300
#  Unrestricted AI in a robot does exactly what experts warned | comments=3446 views=452127
#  Comentarios en inglés aceptados: 300
#  Google’s AI Course for Beginners (in 10 minutes)! | comments=2653 views=3258236
#  Comentarios en inglés aceptados: 300
#  Artificial Intelligence in 2025 | 60 Minutes Full Episodes | comments=1981 views=1500575
#  Comentarios en inglés aceptados: 300
#  AI, Machine Learning, Deep Learning and Generative AI Explained | comments=1914 views=2882963
#  Comentarios en inglés aceptados: 300
#  Harvard CS50’s Artificial Intelligence with Python – Full University C | comments=1773 views=4499769
#  Comentarios en inglés aceptados: 300
#  SIMPLEST Explanation of How Artificial Intelligence Works? No Jargon | | comments=1279 views=1303072
#  Comentarios en inglés aceptados: 300
#  Warp Records - Artificial Intelligence (Full Album) | comments=357 views=157039
#  Comentarios en inglés aceptados: 153
#
#  Query: 'generative AI'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  Generative AI is a Parasitic Cancer | comments=6007 views=524549
#  Comentarios en inglés aceptados: 300
#  "Generative AI" is not what you think it is | comments=4606 views=360521
#  Comentarios en inglés aceptados: 300
#  Generative AI in a Nutshell - how to survive and thrive in the age of  | comments=3956 views=3705312
#  Comentarios en inglés aceptados: 300
#  Has Generative AI Already Peaked? - Computerphile | comments=3886 views=1230251
#  Comentarios en inglés aceptados: 300
#  What Generative AI Users Get Wrong About Artists | comments=2923 views=179619
#  Comentarios en inglés aceptados: 300
#  Generative AI Full Course – Gemini Pro, OpenAI, Llama, Langchain, Pine | comments=2547 views=2947817
#  Comentarios en inglés aceptados: 300
#  Generative AI is not the panacea we’ve been promised | Eric Siegel for | comments=1728 views=987600
#  Comentarios en inglés aceptados: 300
#  Generative AI's Greatest Flaw - Computerphile | comments=999 views=586947
#  Comentarios en inglés aceptados: 300
#  2024 Generative AI Roadmap For Absolute Beginners 🔥 | comments=929 views=616397
#  Comentarios en inglés aceptados: 300
#  Generative AI in Premiere Pro powered by Adobe Firefly | Adobe Video | comments=740 views=659712
#  Comentarios en inglés aceptados: 300
#  Watch this before using generative AI | comments=561 views=1398040
#  Comentarios en inglés aceptados: 82
#  What are Generative AI models? | comments=558 views=1167226
#  Comentarios en inglés aceptados: 300
#  What is generative AI and how does it work? – The Turing Lectures with | comments=495 views=1549815
#  Comentarios en inglés aceptados: 300
#  Introduction to Generative AI | comments=465 views=2212424
#  Comentarios en inglés aceptados: 266
#  Generative AI Explained In 5 Minutes | What Is GenAI? | Introduction T | comments=439 views=2362925
#  Comentarios en inglés aceptados: 109
#
#  Query: 'ChatGPT'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  ChatGPT made me delusional | comments=24996 views=4810319
#  Comentarios en inglés aceptados: 300
#  I Surprised ChatGPT by Speaking Computer Language | comments=13732 views=6141640
#  Comentarios en inglés aceptados: 300
#  I tested the new ChatGPT 5! | comments=5636 views=4180601
#  Comentarios en inglés aceptados: 300
#  How ChatGPT Slowly Destroys Your Brain | comments=4046 views=864722
#  Comentarios en inglés aceptados: 300
#  ChatGPT Tutorial: How to Use Chat GPT For Beginners | comments=1839 views=4572349
#  Comentarios en inglés aceptados: 300
#  Todos Están Desinstalando ChatGPT | comments=1766 views=345526
#  Comentarios en inglés aceptados: 27
#  These ChatGPT Hacks Will Make You SO Productive It Feels Illegal | comments=1112 views=1094362
#  Comentarios en inglés aceptados: 300
#  Gabriel EMC X Alex Zurdo - CHATGPT (Video Oficial) | comments=1092 views=956897
#  Comentarios en inglés aceptados: 8
#  23 Ways to Use ChatGPT So Well it Feels Like Cheating | comments=1076 views=710764
#  Comentarios en inglés aceptados: 300
#  ChatGPT for Beginners - 2026 Edition | comments=669 views=454042
#  Comentarios en inglés aceptados: 300
#  7 Game-Changing ChatGPT Agents That 99% of People Don't Know About | comments=640 views=274722
#  Comentarios en inglés aceptados: 300
#  5 Hacks To Use ChatGPT So Well It’s Almost Unfair | comments=590 views=670793
#  Comentarios en inglés aceptados: 300
#  Millions Cancel ChatGPT: Sam Altman "In Pain" & AI Slop Defeated! | comments=516 views=28333
#  Comentarios en inglés aceptados: 300
#  OpenAI just dropped GPT-5.4 and WOW.... | comments=477 views=100540
#  Comentarios en inglés aceptados: 284
#  Computer Use & Frontend UI with GPT-5.4 Thinking | comments=399 views=121948
#  Comentarios en inglés aceptados: 223
#  What the New ChatGPT 5.4 Means for the World | comments=351 views=46652
#  Comentarios en inglés aceptados: 169
#  AI News: Everyone's Leaving ChatGPT! | comments=263 views=48131
#  Comentarios en inglés aceptados: 202
#
#  Query: 'AI risks'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  The AI Safety Expert: These Are The Only 5 Jobs That Will Remain In 20 | comments=54928 views=15414258
#  Comentarios en inglés aceptados: 300
#  Godfather of AI: They Keep Silencing Me But I’m Trying to Warn Them! | comments=30588 views=12727030
#  Comentarios en inglés aceptados: 300
#  Ex-OpenAI Scientist WARNS: "You Have No Idea What's Coming" | comments=19911 views=5351123
#  Comentarios en inglés aceptados: 300
#  AI 2027: A Realistic Scenario of AI Takeover | comments=19579 views=4277443
#  Comentarios en inglés aceptados: 300
#  AI Expert: Here Is What The World Looks Like In 2 Years! Tristan Harri | comments=16605 views=4338771
#  Comentarios en inglés aceptados: 300
#  Elon Musk tells Tucker potential dangers of hyper-intelligent AI | comments=9845 views=3510097
#  Comentarios en inglés aceptados: 300
#  The threats from AI are real | Sen. Bernie Sanders | comments=9339 views=813092
#  Comentarios en inglés aceptados: 300
#  We’ve Lost Control of AI | comments=8003 views=1797372
#  Comentarios en inglés aceptados: 300
#  An AI Expert Warning: 6 People Are (Quietly) Deciding Humanity’s Futur | comments=7975 views=2328781
#  Comentarios en inglés aceptados: 300
#  The Worst Case Scenario for AI | comments=5760 views=2233739
#  Comentarios en inglés aceptados: 300
#  AI CEO explains the terrifying new behavior AIs are showing | comments=5660 views=1231198
#  Comentarios en inglés aceptados: 300
#  Why AI experts say humans have two years left. Stephen Fry | comments=4207 views=1017799
#  Comentarios en inglés aceptados: 300
#  "Godfather of AI" Geoffrey Hinton: The 60 Minutes Interview | comments=4089 views=4188030
#  Comentarios en inglés aceptados: 300
#  OpenAI’s Sam Altman Talks ChatGPT, AI Agents and Superintelligence — L | comments=4042 views=2222222
#  Comentarios en inglés aceptados: 300
#  Will Artificial Intelligence Destroy Humanity? | comments=3928 views=273419
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI benefits'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  The Truth about Artificial Intelligence and ChatGPT | Dhruv Rathee | comments=31503 views=13167236
#  Comentarios en inglés aceptados: 300
#  A.I. ‐ Humanity's Final Invention? | comments=21340 views=11536676
#  Comentarios en inglés aceptados: 300
#  The Future of Artificial Intelligence By Sandeep Maheshwari | Will Cha | comments=6154 views=4134500
#  Comentarios en inglés aceptados: 300
#  What Is an AI Anyway? | Mustafa Suleyman | TED | comments=3727 views=2712752
#  Comentarios en inglés aceptados: 300
#  How Will People Generate Wealth If AI Does Everything? | comments=3168 views=565212
#  Comentarios en inglés aceptados: 300
#  AI Is Dangerous, but Not for the Reasons You Think | Sasha Luccioni |  | comments=2782 views=1836956
#  Comentarios en inglés aceptados: 300
#  AI & future of workforce: Andrew Yang on how the technology will impac | comments=2526 views=986513
#  Comentarios en inglés aceptados: 300
#  Full interview: "Godfather of AI" shares prediction for future of AI,  | comments=2454 views=1229026
#  Comentarios en inglés aceptados: 300
#  99% of Beginners Don't Know the Basics of AI | comments=2209 views=2922852
#  Comentarios en inglés aceptados: 300
#  9 AI Skills You MUST Have to Become Rich in 2026 | comments=2009 views=1962491
#  Comentarios en inglés aceptados: 300
#  How will AI change the world? | comments=1980 views=2230144
#  Comentarios en inglés aceptados: 300
#  Bill Gates: AI is the biggest technical thing ever in my lifetime | comments=1891 views=870395
#  Comentarios en inglés aceptados: 300
#  How AI Could Save (Not Destroy) Education | Sal Khan | TED | comments=1696 views=2118673
#  Comentarios en inglés aceptados: 300
#  The Catastrophic Risks of AI — and a Safer Path | Yoshua Bengio | TED | comments=1587 views=639109
#  Comentarios en inglés aceptados: 300
#  Why AI Is Our Ultimate Test and Greatest Invitation | Tristan Harris | | comments=792 views=323761
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI ethics'
#  Vídeos seleccionados: 13 (de 50) tras filtros
#  It Begins: An AI Literally Attempted Murder To Avoid Shutdown | comments=37563 views=9838906
#  Comentarios en inglés aceptados: 300
#  We Investigated Al Psychosis. What We Found Will Shock You | comments=14414 views=2272125
#  Comentarios en inglés aceptados: 300
#  Gaslighting ChatGPT With Ethical Dilemmas | comments=8914 views=2928581
#  Comentarios en inglés aceptados: 300
#  AI is an Ethical Nightmare | comments=4329 views=1179678
#  Comentarios en inglés aceptados: 300
#  I Broke ChatGPT's Ethical Guidelines | comments=3364 views=533211
#  Comentarios en inglés aceptados: 300
#  Should I feel guilty using AI? | comments=1868 views=430308
#  Comentarios en inglés aceptados: 300
#  AI and human evolution | Yuval Noah Harari | comments=901 views=548093
#  Comentarios en inglés aceptados: 300
#  AI Ethics WITH an AI | comments=674 views=245116
#  Comentarios en inglés aceptados: 300
#  OpenAI CEO Sam Altman on AI governance, ethics, and innovation | A con | comments=262 views=83995
#  Comentarios en inglés aceptados: 130
#  xQc Tests AI Ethics with the Trolley Problem | comments=250 views=77325
#  Comentarios en inglés aceptados: 139
#
#  Query: 'AI regulation'
#  Vídeos seleccionados: 11 (de 50) tras filtros
#  7 Laws To Stop AI From Killing Us All | comments=2339 views=135375
#  Comentarios en inglés aceptados: 300
#  America's AI Regulation Ban Is Back | comments=1717 views=94996
#  Comentarios en inglés aceptados: 300
#  Demis Hassabis On The Future of Work in the Age of AI | comments=1705 views=730301
#  Comentarios en inglés aceptados: 300
#  US Senate Just Killed The 10-Year AI Regulation Ban | comments=1057 views=184304
#  Comentarios en inglés aceptados: 300
#  The EU's AI Act Explained | comments=733 views=100337
#  Comentarios en inglés aceptados: 300
#  Anthropic CEO speaks about 'powerful' AI risks and regulation | comments=665 views=226693
#  Comentarios en inglés aceptados: 300
#  Trump expected to sign order blocking state AI regulation | comments=572 views=24535
#  Comentarios en inglés aceptados: 291
#  The Race To Regulate AI | comments=214 views=104803
#  Comentarios en inglés aceptados: 117
#
#  Query: 'AI bias'
#  Vídeos seleccionados: 2 (de 50) tras filtros
#  Is the AI Left-Bias Real? | comments=5151 views=311455
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI in education'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  AI is DESTROYING education | comments=3513 views=206233
#  Comentarios en inglés aceptados: 300
#  Veritasium: What Everyone Gets Wrong About AI and Learning – Derek Mul | comments=3472 views=4876861
#  Comentarios en inglés aceptados: 300
#  Everyone is Cheating (Even the Professors) | comments=3129 views=1237696
#  Comentarios en inglés aceptados: 300
#  How AI is Ruining Education For Everyone | comments=2453 views=407941
#  Comentarios en inglés aceptados: 300
#  How AI Is Destroying Education | comments=1321 views=218987
#  Comentarios en inglés aceptados: 300
#  No teachers, no homework: School solely uses AI to teach students | comments=1070 views=330960
#  Comentarios en inglés aceptados: 300
#  You’re Not Behind (Yet): How to Learn AI in 29 Minutes | comments=979 views=865342
#  Comentarios en inglés aceptados: 300
#  AI bubble disaster in education | comments=675 views=32874
#  Comentarios en inglés aceptados: 300
#  AI Will Destroy Education, Teachers and Schools if we don't stop it | comments=667 views=38308
#  Comentarios en inglés aceptados: 300
#  Is AI making us dumber? Maybe. | Charlie Gedeon | TEDxSherbrooke Stree | comments=483 views=287540
#  Comentarios en inglés aceptados: 296
#  ‘20 PhDs’ In the Time of One: How AI Is Changing College | comments=456 views=240361
#  Comentarios en inglés aceptados: 258
#  Should we let students use ChatGPT? | Natasha Berg | TEDxSioux Falls | comments=384 views=423427
#  Comentarios en inglés aceptados: 205
#  AI & Education: Generative AI & the Future of Critical Thinking | comments=352 views=142015
#  Comentarios en inglés aceptados: 241
#  What is the Future of Education? Freakonomics’ Steve Levitt & Google C | comments=267 views=1584472
#  Comentarios en inglés aceptados: 166
#  everyone is putting AI in schools...... | comments=242 views=94062
#  Comentarios en inglés aceptados: 175
#
#  Query: 'ChatGPT students cheating'
#  Vídeos seleccionados: 8 (de 50) tras filtros
#  PhD student expelled from University of Minnesota for allegedly using  | comments=8349 views=2470057
#  Comentarios en inglés aceptados: 300
#  College student sues after being expelled, accused of using ChatGPT on | comments=3834 views=682310
#  Comentarios en inglés aceptados: 300
#  Teachers, Your Students Are (Probably) Cheating | comments=2454 views=236511
#  Comentarios en inglés aceptados: 300
#  Students are CHEATING with Ai ChatGPT | comments=1256 views=221210
#  Comentarios en inglés aceptados: 300
#  How Everyone Is Cheating Their Way Through College - What happens next | comments=200 views=8114
#  Comentarios en inglés aceptados: 97
#
#  Query: 'ChatGPT learning tool'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  How to use ChatGPT to easily learn any skill you want | comments=2475 views=2049333
#  Comentarios en inglés aceptados: 300
#  How to Get Ahead of 99% of People (with AI) | comments=1984 views=1711407
#  Comentarios en inglés aceptados: 300
#  Ultimate AI Masterclass For Beginners [Free Course] - Learn ChatGPT, P | comments=1169 views=214401
#  Comentarios en inglés aceptados: 300
#  How to Go From ChatGPT Beginner to Pro in 2026 | comments=615 views=261951
#  Comentarios en inglés aceptados: 300
#  How To Use ChatGPT To Learn ANY Skill Quickly (Tutorial) | comments=560 views=1708343
#  Comentarios en inglés aceptados: 300
#  How To Learn ANY Language With These ChatGPT Prompts | comments=526 views=530059
#  Comentarios en inglés aceptados: 228
#  ChatGPT Study Mode - Explained By A Learning Expert | comments=492 views=255404
#  Comentarios en inglés aceptados: 300
#  10 Ways to Use ChatGPT So Well It Feels Illegal (Tutorial) | comments=482 views=1270721
#  Comentarios en inglés aceptados: 300
#  Oxford Researchers Discovered How to Use AI To Learn Like A Genius | comments=411 views=296031
#  Comentarios en inglés aceptados: 300
#  How to learn anything fast using ChatGPT | Full guide to studying with | comments=271 views=489734
#  Comentarios en inglés aceptados: 184
#  ChatGPT Tutorial: 35 Tips I Wish I Knew Sooner | comments=253 views=263743
#  Comentarios en inglés aceptados: 195
#  The new method to learn a language with Chat GPT5 | comments=206 views=75503
#  Comentarios en inglés aceptados: 85
#
#  Query: 'AI replacing teachers'
#  Vídeos seleccionados: 10 (de 50) tras filtros
#  SCHOOL USES AI TEACHERS!! | comments=6504 views=4160647
#  Comentarios en inglés aceptados: 300
#  AI TEACHERS Run The School | Dhar Mann Studios | comments=4553 views=6190036
#  Comentarios en inglés aceptados: 300
#  A.I. Teachers and Duolingo’s New Plan — What Could Go Wrong? | comments=3014 views=1349002
#  Comentarios en inglés aceptados: 300
#  Real Teacher Gets Replaced By AI Robot | comments=1452 views=927448
#  Comentarios en inglés aceptados: 300
#  This $40M AI Company Is Using AI Tutors to Teach 2 Hours/Day | #233 | comments=643 views=90090
#  Comentarios en inglés aceptados: 300
#  "We Don't Need Public Schools" - Can AI Replace Teachers? | comments=559 views=45290
#  Comentarios en inglés aceptados: 300
#  Will artificial intelligence replace teachers in classrooms? | The Str | comments=343 views=114328
#  Comentarios en inglés aceptados: 222
#
#  Query: 'ChatGPT homework students'
#  Vídeos seleccionados: 2 (de 25) tras filtros
#  English Teacher Grades Homework By ChatGPT | WIRED | comments=863 views=564055
#  Comentarios en inglés aceptados: 300
#
#  Query: 'artificial intelligence school'
#  Vídeos seleccionados: 10 (de 50) tras filtros
#  Trump education secretary embarrassingly out of touch on artificial in | comments=3539 views=479475
#  Comentarios en inglés aceptados: 300
#  Educating Kids in the Age of A.I. | The Ezra Klein Show | comments=1406 views=391302
#  Comentarios en inglés aceptados: 300
#  "Is AI destroying education?" | Middle Ground | comments=647 views=593208
#  Comentarios en inglés aceptados: 300
#  AI Basics for Beginners | comments=428 views=669038
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI for learning'
#  Vídeos seleccionados: 13 (de 25) tras filtros
#  You’re Not Behind (Yet): How to Learn AI in 17 Minutes | comments=2643 views=3085435
#  Comentarios en inglés aceptados: 300
#  These 5 Ways to Use AI Will Make You $1M (Anyone Can Start) | comments=1304 views=482077
#  Comentarios en inglés aceptados: 300
#  Free AI COURSE for Beginners – Class 1 - What is AI? How AI Works? #co | comments=802 views=739765
#  Comentarios en inglés aceptados: 212
#  AI Tools EXPLAINED:  How to Use Them? (2025 Guide for Beginners) | comments=418 views=513551
#  Comentarios en inglés aceptados: 300
#  Don't learn AI Agents without Learning these Fundamentals | comments=357 views=507727
#  Comentarios en inglés aceptados: 279
#  You’re not behind (yet): How to learn AI in 18 minutes | comments=331 views=109063
#  Comentarios en inglés aceptados: 152
#  You’re Not Behind (Yet): How to Learn AI in 19 Minutes | comments=210 views=169006
#  Comentarios en inglés aceptados: 137
#
#  Query: 'AI and jobs future'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  AI AGENTS DEBATE: These Jobs Won't Exist In 24 Months! | comments=16409 views=3364980
#  Comentarios en inglés aceptados: 300
#  If AI Takes All Of Our Jobs... Who's Going To Buy Everything? | comments=13945 views=3107463
#  Comentarios en inglés aceptados: 300
#  Yes, AI Will Take Your Job. But What Happens NEXT Is Worse | comments=9842 views=895627
#  Comentarios en inglés aceptados: 300
#  AI company's CEO issues warning about mass unemployment | comments=8715 views=2120495
#  Comentarios en inglés aceptados: 300
#  Godfather of AI: We Have 2 Years Before Everything Changes! | comments=5031 views=1803341
#  Comentarios en inglés aceptados: 300
#  If AI erases 85 million jobs... then what? | comments=3959 views=256265
#  Comentarios en inglés aceptados: 300
#  AI Will Erase 300 Million Jobs By 2030 (Do This NOW To Survive) | comments=3314 views=604220
#  Comentarios en inglés aceptados: 300
#  WARNING: These Jobs WON'T Exist in 24 Months! | comments=2988 views=639356
#  Comentarios en inglés aceptados: 300
#  What jobs will be done by AI in 10 years? 🤖 | comments=2603 views=1478098
#  Comentarios en inglés aceptados: 300
#  AI Experts: These Are The Only 5 Jobs That Will Remain in 2030! | comments=2478 views=865021
#  Comentarios en inglés aceptados: 300
#  Bill Gates on navigating an AI future | comments=1428 views=529883
#  Comentarios en inglés aceptados: 300
#  What Everyone Is Getting Wrong About AI And Jobs | comments=876 views=307303
#  Comentarios en inglés aceptados: 300
#  Jobs AI Will Never Replace, Study Finds | comments=823 views=300759
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI taking jobs'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  AI Could Wipe Out the Working Class | Sen. Bernie Sanders | comments=20060 views=2007293
#  Comentarios en inglés aceptados: 300
#  If AI Takes Over, We Lose Our Jobs... BUT If AI Fails... We Also Lose  | comments=4714 views=833497
#  Comentarios en inglés aceptados: 300
#  How AI is Causing a White Collar Bloodbath | comments=3975 views=1424528
#  Comentarios en inglés aceptados: 300
#  'Godfather of AI' predicts ALL jobs will be in 'wiped out' by AI | comments=2576 views=380072
#  Comentarios en inglés aceptados: 300
#  i've changed my mind about AI taking our jobs.... | comments=2417 views=117873
#  Comentarios en inglés aceptados: 300
#  AI Will Replace White Collar Jobs in 12 Months? The Truth No One Expla | comments=1875 views=208382
#  Comentarios en inglés aceptados: 300
#  'AI won't just take your job, it will take EVERY job' | comments=1113 views=94670
#  Comentarios en inglés aceptados: 300
#  How AI is changing the job market - What in the World podcast, BBC Wor | comments=804 views=589961
#  Comentarios en inglés aceptados: 300
#  Economist explains what happens after AI takes all jobs | comments=742 views=88538
#  Comentarios en inglés aceptados: 300
#  Examining which careers are most at-risk for AI impacts | comments=736 views=188347
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI creating jobs'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  How AI Is Killing The Value Of A College Degree | comments=5240 views=1360774
#  Comentarios en inglés aceptados: 300
#  I Got Rejected 100 Times So I Built My Own Job With AI | comments=1972 views=211765
#  Comentarios en inglés aceptados: 300
#  Future of Work 2026: The Only Jobs That Will Survive the AI Era | comments=343 views=181253
#  Comentarios en inglés aceptados: 202
#  How the AI Boom is Creating Electrician Jobs for Young Workers | comments=317 views=91499
#  Comentarios en inglés aceptados: 129
#  AI’s Hottest New Job Pays Up to $250K a Year. So I Applied. | WSJ | comments=316 views=438667
#  Comentarios en inglés aceptados: 190
#  AI Is Already Taking Tech Jobs | comments=245 views=103343
#  Comentarios en inglés aceptados: 135
#
#  Query: 'new jobs artificial intelligence'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  AI’s job shake-up is accelerating. Is it time for universal basic inco | comments=4882 views=661584
#  Comentarios en inglés aceptados: 300
#  The graduate 'jobpocalypse':  Where have all the entry-level jobs gone | comments=1779 views=1303986
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI employment'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  The REAL Reason ONLY 5 Jobs Will EXIST in 24 Months | comments=6572 views=1114051
#  Comentarios en inglés aceptados: 300
#  AI and the Death of the Career Ladder | comments=3416 views=639914
#  Comentarios en inglés aceptados: 300
#  How AI Layoffs Could Backfire On Employers | comments=1989 views=879712
#  Comentarios en inglés aceptados: 300
#  The AI rollout is here - and it's messy | FT Working It | comments=1160 views=579285
#  Comentarios en inglés aceptados: 300
#  UK unemployment soars: is AI already taking our jobs? | comments=962 views=106624
#  Comentarios en inglés aceptados: 300
#
#  Query: 'AI unemployment'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  'Musk Will Get Richer, People Will Get Unemployed': Nobel Laureate Hin | comments=2814 views=1422306
#  Comentarios en inglés aceptados: 300
#  The AI Collapse Is MUCH Worse Than You Think | comments=1046 views=303261
#  Comentarios en inglés aceptados: 300
#  The AI Job Crisis Is Worse Than You Think (40% Unemployment?!) | comments=900 views=66905
#  Comentarios en inglés aceptados: 300
#
#  Query: 'will AI take my job'
#  Vídeos seleccionados: 17 (de 50) tras filtros
#  I Lost My Job to AI | comments=5669 views=840307
#  Comentarios en inglés aceptados: 300
#  A.I. Tries 20 Jobs | WIRED | comments=3627 views=809749
#  Comentarios en inglés aceptados: 300
#  AI Can’t Do Your Job. So Why Are Companies Laying Off Employees? | comments=1280 views=110082
#  Comentarios en inglés aceptados: 300
#
#  Query: 'ChatGPT replace workers'
#  Vídeos seleccionados: 2 (de 50) tras filtros
#
#  Total comentarios en inglés recogidos: 50979
#       video_id                  comment_id  \
# 0  5KmopXwjXik  UgznfE7J62Zc2cOBXpF4AaABAg
# 1  5KmopXwjXik  Ugyv0fb5gJkkObw0qbt4AaABAg
# 2  5KmopXwjXik  Ugzduwz4V983bhyXFc14AaABAg
# 3  5KmopXwjXik  UgwUYU2Q1cK6zMHj4eh4AaABAg
# 4  5KmopXwjXik  UgyD_g4EIKmh8FLa7qB4AaABAg
#
#                                                 text  likes  \
# 0  Watch the full episode here - https://youtu.be...    288
# 1  AI while creating maybe easy and efficient way...      0
# 2  AI will take over, just watch, this is what Tr...      1
# 3  Holistico punto humano watsu moxibustion shiat...      0
# 4  TODO LO MENTIROSO ENGAÑADOR Y MALO\n\nNOOOO,,,...      0
#
#                    date                         author  reply_count  \
# 0  2025-09-28T20:06:59Z           @TheDiaryOfACEOClips           53
# 1  2026-03-06T22:38:04Z    @PatoimboumbouCompissorater            0
# 2  2026-03-05T23:25:40Z                       @rob8392            0
# 3  2026-03-05T12:12:35Z  @EnfermeriaHolisticoterapeuta            0
# 4  2026-03-05T11:31:53Z                   @Maria-u9q7j            0
#
#                                          video_title  \
# 0  Godfather of AI WARNS: "You Have No Idea What'...
# 1  Godfather of AI WARNS: "You Have No Idea What'...
# 2  Godfather of AI WARNS: "You Have No Idea What'...
# 3  Godfather of AI WARNS: "You Have No Idea What'...
# 4  Godfather of AI WARNS: "You Have No Idea What'...
#
#                     channel          published_at               query_used  \
# 0  The Diary Of A CEO Clips  2025-09-27T18:00:03Z  artificial intelligence
# 1  The Diary Of A CEO Clips  2025-09-27T18:00:03Z  artificial intelligence
# 2  The Diary Of A CEO Clips  2025-09-27T18:00:03Z  artificial intelligence
# 3  The Diary Of A CEO Clips  2025-09-27T18:00:03Z  artificial intelligence
# 4  The Diary Of A CEO Clips  2025-09-27T18:00:03Z  artificial intelligence
#
#    video_viewCount  video_commentCount  video_duration_sec
# 0          5683925               14931                1257
# 1          5683925               14931                1257
# 2          5683925               14931                1257
# 3          5683925               14931                1257
# 4          5683925               14931                1257

# %%
df["date"] = pd.to_datetime(df["date"])
df.groupby("video_id")["date"].agg(["min","max","count"]).sort_values("count", ascending=False).head(10)
# Out:
#                                   min                       max  count
# video_id
# -opBifFfsMY 2025-01-02 23:44:09+00:00 2026-02-16 16:47:11+00:00    300
# 0lwftepuvYA 2026-02-25 19:57:13+00:00 2026-03-07 06:29:02+00:00    300
# 0tLHVyd7WtM 2025-08-22 15:01:33+00:00 2026-03-07 00:23:58+00:00    300
# 0xS68sl2D70 2025-10-01 23:46:17+00:00 2026-03-04 19:51:52+00:00    300
# 2IK3DFHRFfw 2025-01-10 11:04:56+00:00 2026-02-28 13:47:36+00:00    300
# 1UufaK3pQMg 2025-08-02 17:32:09+00:00 2026-03-07 01:54:38+00:00    300
# 5KmopXwjXik 2025-09-28 20:06:59+00:00 2026-03-06 22:38:04+00:00    300
# 4lKuEvu9opQ 2026-01-09 04:59:23+00:00 2026-03-07 09:22:35+00:00    300
# 79-bApI3GIU 2026-02-07 14:08:26+00:00 2026-03-06 23:10:31+00:00    300
# 7AGa5z69zqU 2025-10-15 17:29:52+00:00 2026-03-04 13:16:24+00:00    300

# %%
df["date"] = pd.to_datetime(df["date"], utc=True)

span = (df.groupby("video_id")["date"].max() - df.groupby("video_id")["date"].min()).sort_values(ascending=False)
span.head(10)
# Out:
# video_id
# jaysR-sashY   1139 days 13:41:32
# nneN5MyE6d8   1102 days 23:37:15
# Gaf_jCnA6mc   1061 days 23:00:39
# hfIUstzHs9A   1059 days 18:50:14
# G2fqAlgmoPo   1019 days 06:40:21
# vjKOIFnuZHE   1018 days 17:48:15
# RzkD_rTEBYs   1004 days 14:51:21
# vYvOTGk7hOA    965 days 12:39:53
# vJefOB8kec8    955 days 02:13:58
# tTagNMmzgQo    909 days 00:35:41
# Name: date, dtype: timedelta64[ns]

# %%
n_videos = df["video_id"].nunique()
n_comments = len(df)
print("videos:", n_videos, "| comments:", n_comments, "| avg comments/video:", n_comments / n_videos)
# Out:
# videos: 184 | comments: 50979 | avg comments/video: 277.0597826086956

# %%
n_videos = df["video_id"].nunique()
n_comments = len(df)
top_channels = df["channel"].value_counts().head(10)

print("videos:", n_videos)
print("comments:", n_comments)
print("avg comments/video:", round(n_comments/n_videos, 1))
print("\nTop 10 channels by comments:\n", top_channels)
# Out:
# videos: 184
# comments: 50979
# avg comments/video: 277.1
#
# Top 10 channels by comments:
#  channel
# Dan Martell                  1952
# TED                          1800
# The Diary Of A CEO           1800
# CNN                          1200
# The Diary Of A CEO Clips      900
# Species | Documenting AGI     900
# 60 Minutes                    900
# WIRED                         900
# Siliconversations             900
# Charlie Chang                 899
# Name: count, dtype: int64

# %%
print("videos:", df["video_id"].nunique())
print("channels:", df["channel"].nunique())
print("comments:", len(df))
# Out:
# videos: 184
# channels: 129
# comments: 50979

# %%
top10_vid_share = df["video_id"].value_counts(normalize=True).head(10).sum()
top10_ch_share = df["channel"].value_counts(normalize=True).head(10).sum()
print("Top10 videos share:", round(top10_vid_share,3))
print("Top10 channels share:", round(top10_ch_share,3))
# Out:
# Top10 videos share: 0.059
# Top10 channels share: 0.238

# %%
df["date"] = pd.to_datetime(df["date"], utc=True)
monthly = df.set_index("date").resample("M").size()
monthly.tail(24)
# Out:
# C:\Users\mbgaz\AppData\Local\Temp\ipykernel_13388\3803432215.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = df.set_index("date").resample("M").size()
# date
# 2024-04-30 00:00:00+00:00     460
# 2024-05-31 00:00:00+00:00     202
# 2024-06-30 00:00:00+00:00     172
# 2024-07-31 00:00:00+00:00     132
# 2024-08-31 00:00:00+00:00     396
# 2024-09-30 00:00:00+00:00     542
# 2024-10-31 00:00:00+00:00     295
# 2024-11-30 00:00:00+00:00     340
# 2024-12-31 00:00:00+00:00     225
# 2025-01-31 00:00:00+00:00     587
# 2025-02-28 00:00:00+00:00     391
# 2025-03-31 00:00:00+00:00     467
# 2025-04-30 00:00:00+00:00     949
# 2025-05-31 00:00:00+00:00    1433
# 2025-06-30 00:00:00+00:00    1560
# 2025-07-31 00:00:00+00:00    1785
# 2025-08-31 00:00:00+00:00    1939
# 2025-09-30 00:00:00+00:00    1974
# 2025-10-31 00:00:00+00:00    3926
# 2025-11-30 00:00:00+00:00    4575
# 2025-12-31 00:00:00+00:00    6211
# 2026-01-31 00:00:00+00:00    6933
# 2026-02-28 00:00:00+00:00    8662
# 2026-03-31 00:00:00+00:00    3909
# Freq: ME, dtype: int64
