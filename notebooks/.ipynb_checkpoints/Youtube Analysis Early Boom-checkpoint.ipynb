# %%
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError
import pandas as pd
import time
import isodate
from langdetect import detect, LangDetectException

API_KEY = "AIzaSyA15-WpNlkEbaRcvwoOq7QtiUYUSvUeHx8"
youtube = build("youtube", "v3", developerKey=API_KEY)

# -----------------------------
# Utilidad: ejecutar con retries
# -----------------------------
def execute_with_retries(request, max_retries=5, base_sleep=1.5):
    for i in range(max_retries):
        try:
            return request.execute()
        except HttpError as e:
            if e.resp.status == 400:
                print(f"Error 400 (parámetro inválido): {e.content.decode()}")
                raise
            sleep_s = base_sleep * (2 ** i)
            print(f"HTTPError ({e.resp.status}). Reintentando en {sleep_s:.1f}s...")
            time.sleep(sleep_s)
    raise RuntimeError("Demasiados errores seguidos con la API (retries agotados).")

# -----------------------------
# Filtro de idioma inglés
# -----------------------------
def is_english(text, min_length=15):
    if not text or len(text.strip()) < min_length:
        return False
    try:
        return detect(text) == "en"
    except LangDetectException:
        return False

# -----------------------------------------------
# 1) Buscar vídeos (solo IDs) por término y fecha
# -----------------------------------------------
def search_video_ids(query, max_results=50, published_after=None, published_before=None, relevance_language="en"):
    video_ids = []

    params = {
        "part": "id",
        "q": query,
        "type": "video",
        "order": "relevance",
        "maxResults": min(max_results, 50),
        "relevanceLanguage": relevance_language
    }

    # Solo añadir fechas si no son None
    if published_after:
        params["publishedAfter"] = published_after
    if published_before:
        params["publishedBefore"] = published_before

    request = youtube.search().list(**params)
    response = execute_with_retries(request)
    for item in response.get("items", []):
        video_ids.append(item["id"]["videoId"])
    return list(dict.fromkeys(video_ids))

# ---------------------------------------------------------
# 2) Enriquecer vídeos: stats + duración + snippet (batch)
# ---------------------------------------------------------
def fetch_video_metadata(video_ids):
    rows = []
    for i in range(0, len(video_ids), 50):
        chunk = video_ids[i:i+50]
        request = youtube.videos().list(
            part="snippet,statistics,contentDetails",
            id=",".join(chunk)
        )
        response = execute_with_retries(request)

        for v in response.get("items", []):
            stats = v.get("statistics", {})
            cd = v.get("contentDetails", {})
            sn = v.get("snippet", {})

            duration_sec = None
            if "duration" in cd:
                try:
                    duration_sec = int(isodate.parse_duration(cd["duration"]).total_seconds())
                except Exception:
                    duration_sec = None

            rows.append({
                "video_id": v["id"],
                "title": sn.get("title"),
                "channel": sn.get("channelTitle"),
                "channel_id": sn.get("channelId"),
                "published_at": sn.get("publishedAt"),
                "description": sn.get("description"),
                "duration_sec": duration_sec,
                "viewCount": int(stats.get("viewCount", 0)) if stats.get("viewCount") else 0,
                "likeCount": int(stats.get("likeCount", 0)) if stats.get("likeCount") else 0,
                "commentCount": int(stats.get("commentCount", 0)) if stats.get("commentCount") else 0,
            })

    return pd.DataFrame(rows)

# -----------------------------------------------
# 3) Obtener comentarios top-level (paginando)
# -----------------------------------------------
def get_comments(video_id, max_comments=500, order="time"):
    comments = []
    request = youtube.commentThreads().list(
        part="snippet",
        videoId=video_id,
        maxResults=100,
        textFormat="plainText",
        order=order
    )

    while request and len(comments) < max_comments:
        response = execute_with_retries(request)

        for item in response.get("items", []):
            snippet = item["snippet"]["topLevelComment"]["snippet"]
            text = snippet.get("textDisplay", "")

            if not is_english(text):
                continue

            comments.append({
                "video_id": video_id,
                "comment_id": item["snippet"]["topLevelComment"]["id"],
                "text": text,
                "likes": snippet.get("likeCount", 0),
                "date": snippet.get("publishedAt"),
                "author": snippet.get("authorDisplayName"),
                "reply_count": item["snippet"].get("totalReplyCount", 0),
            })

            if len(comments) >= max_comments:
                break

        request = youtube.commentThreads().list_next(request, response)

    return comments

# -----------------------------------------------
# 4) Pipeline completo
# -----------------------------------------------
def collect_youtube_data(
    queries,
    max_videos_per_query=10,
    max_comments_per_video=300,
    published_after=None,
    published_before=None,
    relevance_language="en",
    min_comment_count=200,
    min_duration_sec=180,
    comment_order="time",
    comment_year_min=2020,
    comment_year_max=2023
):
    all_comments = []
    seen_comment_ids = set()
    seen_video_ids = set()

    for query in queries:
        print(f"\n Query: '{query}'")

        ids = search_video_ids(
            query=query,
            max_results=50,
            published_after=published_after,
            published_before=published_before,
            relevance_language=relevance_language
        )

        if not ids:
            print("Sin resultados para esta query.")
            continue

        meta = fetch_video_metadata(ids)

        # Filtrar vídeos por fecha de publicación manualmente (doble seguridad)
        if published_after:
            year_after = int(published_after[:4])
            meta = meta[pd.to_datetime(meta["published_at"], errors="coerce").dt.year >= year_after]
        if published_before:
            year_before = int(published_before[:4])
            meta = meta[pd.to_datetime(meta["published_at"], errors="coerce").dt.year < year_before]

        filtered = meta[
            (meta["commentCount"] >= min_comment_count) &
            (meta["duration_sec"].fillna(999999) >= min_duration_sec)
        ].copy()

        filtered = filtered.sort_values(["commentCount", "viewCount"], ascending=False)
        selected = filtered.head(max_videos_per_query)

        print(f"Vídeos seleccionados: {len(selected)} (de {len(meta)}) tras filtros")

        for _, v in selected.iterrows():
            vid = v["video_id"]
            if vid in seen_video_ids:
                continue
            seen_video_ids.add(vid)

            print(f"{v['title'][:70]} | comments={v['commentCount']} views={v['viewCount']}")

            try:
                comments = get_comments(vid, max_comments=max_comments_per_video, order=comment_order)
            except Exception as e:
                print(f"Error comentarios en {vid}: {e}")
                continue

            accepted = 0
            for c in comments:
                cid = c.get("comment_id")
                if cid and cid in seen_comment_ids:
                    continue
                if cid:
                    seen_comment_ids.add(cid)

                # Filtro temporal de comentarios
                comment_date = c.get("date", "")
                if comment_date:
                    try:
                        year = int(comment_date[:4])
                        if year < comment_year_min or year > comment_year_max:
                            continue
                    except ValueError:
                        continue

                c["video_title"] = v["title"]
                c["channel"] = v["channel"]
                c["published_at"] = v["published_at"]
                c["query_used"] = query
                c["video_viewCount"] = v["viewCount"]
                c["video_commentCount"] = v["commentCount"]
                c["video_duration_sec"] = v["duration_sec"]

                all_comments.append(c)
                accepted += 1

            print(f"Comentarios en inglés ({comment_year_min}-{comment_year_max}) aceptados: {accepted}")

    return pd.DataFrame(all_comments)

# -------------------
# 5) Ejecutar
# -------------------
queries = [
    # General IA
    "artificial intelligence",
    "generative AI",
    "ChatGPT",
    "AI risks",
    "AI benefits",
    "AI ethics",

    # Educación
    "AI in education",
    "ChatGPT learning tool",
    "AI replacing teachers",
    "ChatGPT homework students",
    "artificial intelligence school",
    "AI for learning",
    

    # Empleo
    "AI and jobs future",
    "AI taking jobs",
    "AI creating jobs",
    "new jobs artificial intelligence",
    "AI employment",
    "AI unemployment",
    "will AI take my job",
    "ChatGPT replace workers",
]

df = collect_youtube_data(
    queries=queries,
    max_videos_per_query=15,
    max_comments_per_video=300,
    published_after="2020-01-01T00:00:00.000Z",
    published_before="2024-01-01T00:00:00.000Z",
    relevance_language="en",
    min_comment_count=200,
    min_duration_sec=180,
    comment_order="time",
    comment_year_min=2020,
    comment_year_max=2023
)

df.to_csv("youtube_comments_AI_2020_2023.csv", index=False)
print(f"\n Total comentarios recogidos (2020-2023): {len(df)}")
df.head()
# Out:
#  Query: 'artificial intelligence'
# Vídeos seleccionados: 15 (de 38) tras filtros
# The Truth about Artificial Intelligence and ChatGPT | Dhruv Rathee | comments=31503 views=13167228
# Comentarios en inglés (2020-2023) aceptados: 1
# Artificial Intelligence Out of Control: The Apocalypse is Here | How A | comments=19747 views=4815200
# Comentarios en inglés (2020-2023) aceptados: 1
# Sky News Australia interviews 'free-thinking' artificial intelligence | comments=11795 views=3344205
# Comentarios en inglés (2020-2023) aceptados: 0
# Artificial Intelligence: Last Week Tonight with John Oliver (HBO) | comments=11278 views=11528117
# Comentarios en inglés (2020-2023) aceptados: 0
# Artificial Intelligence | 60 Minutes Full Episodes | comments=8079 views=9276152
# Comentarios en inglés (2020-2023) aceptados: 0
# "Godfather of AI" Geoffrey Hinton: The 60 Minutes Interview | comments=4089 views=4188027
# Comentarios en inglés (2020-2023) aceptados: 0
# Artificial Intelligence (Official Video) | comments=3534 views=2704404
# Comentarios en inglés (2020-2023) aceptados: 69
# AI Is Dangerous, but Not for the Reasons You Think | Sasha Luccioni |  | comments=2782 views=1836956
# Comentarios en inglés (2020-2023) aceptados: 0
# Google’s AI Course for Beginners (in 10 minutes)! | comments=2653 views=3258233
# Comentarios en inglés (2020-2023) aceptados: 1
# The 10 Stages of Artificial Intelligence | comments=2619 views=1645621
# Comentarios en inglés (2020-2023) aceptados: 1
# Full interview: "Godfather of artificial intelligence" talks impact an | comments=2445 views=1978552
# Comentarios en inglés (2020-2023) aceptados: 189
# Harvard CS50’s Artificial Intelligence with Python – Full University C | comments=1773 views=4499754
# Comentarios en inglés (2020-2023) aceptados: 0
# How does artificial intelligence learn? - Briana Brownell | comments=1305 views=811464
# Comentarios en inglés (2020-2023) aceptados: 232
# What is AI? Artificial Intelligence Explained | comments=1078 views=1487064
# Comentarios en inglés (2020-2023) aceptados: 158
# How to Learn AI | Effect of AI on Freelancers | comments=791 views=1291855
# Comentarios en inglés (2020-2023) aceptados: 121
#
#  Query: 'generative AI'
# Vídeos seleccionados: 12 (de 37) tras filtros
# Generative AI Is About To Reset Everything, And, Yes It Will Change Yo | comments=1923 views=1038884
# Comentarios en inglés (2020-2023) aceptados: 285
# How AI Could Save (Not Destroy) Education | Sal Khan | TED | comments=1696 views=2118673
# Comentarios en inglés (2020-2023) aceptados: 4
# What's the future for generative AI? - The Turing Lectures with Mike W | comments=811 views=575090
# Comentarios en inglés (2020-2023) aceptados: 107
# Watch this before using generative AI | comments=561 views=1398032
# Comentarios en inglés (2020-2023) aceptados: 10
# What are Generative AI models? | comments=558 views=1167225
# Comentarios en inglés (2020-2023) aceptados: 209
# What is Generative AI? It’s going to alter everything about how we use | comments=501 views=501183
# Comentarios en inglés (2020-2023) aceptados: 200
# What is generative AI and how does it work? – The Turing Lectures with | comments=495 views=1549815
# Comentarios en inglés (2020-2023) aceptados: 48
# Introduction to Generative AI | comments=465 views=2212424
# Comentarios en inglés (2020-2023) aceptados: 165
# How Large Language Models Work | comments=383 views=1387594
# Comentarios en inglés (2020-2023) aceptados: 27
# What Will Happen to Marketing in the Age of AI? | Jessica Apotheker |  | comments=374 views=853514
# Comentarios en inglés (2020-2023) aceptados: 47
# What are the risks of generative AI? - The Turing Lectures with Mhairi | comments=201 views=53152
# Comentarios en inglés (2020-2023) aceptados: 79
#
#  Query: 'ChatGPT'
# Vídeos seleccionados: 15 (de 50) tras filtros
# How to Use ChatGPT to Ruin Your Legal Career | comments=7930 views=5736558
# Comentarios en inglés (2020-2023) aceptados: 1
# Testing the limits of ChatGPT and discovering a dark side | comments=6017 views=3949996
# Comentarios en inglés (2020-2023) aceptados: 0
# Google vs. ChatGPT: INSANE CHESS | comments=5633 views=3649575
# Comentarios en inglés (2020-2023) aceptados: 0
# If ChatGPT was ASIAN | comments=5488 views=5356672
# Comentarios en inglés (2020-2023) aceptados: 1
# 10 ChatGPT Life Hacks - THAT’LL CHANGE YOUR LIFE !! | comments=3205 views=3124684
# Comentarios en inglés (2020-2023) aceptados: 0
# ChatGPT Tutorial - A Crash Course on Chat GPT for Beginners | comments=2627 views=6007595
# Comentarios en inglés (2020-2023) aceptados: 198
# ChatGPT Tutorial: How to Use Chat GPT For Beginners | comments=1839 views=4572328
# Comentarios en inglés (2020-2023) aceptados: 1
# Master the Perfect ChatGPT Prompt Formula (in just 8 minutes)! | comments=1778 views=3468420
# Comentarios en inglés (2020-2023) aceptados: 1
# Don't Use ChatGPT Until You Watch This Video | comments=1219 views=1992013
# Comentarios en inglés (2020-2023) aceptados: 1
# I Asked ChatGPT To Make Me As Much Money As Possible | comments=1045 views=2297308
# Comentarios en inglés (2020-2023) aceptados: 100
# CHAT GPT: QUÉ ES, CÓMO FUNCIONA y HASTA DÓNDE PUEDE LLEGAR | comments=545 views=1021700
# Comentarios en inglés (2020-2023) aceptados: 2
# Chat GPT Complete Urdu Tutorial || Chat GPT Kaise Use Kare? | comments=375 views=846490
# Comentarios en inglés (2020-2023) aceptados: 58
# O QUE É, COMO ACESSAR E COMO USAR O CHATGPT? | comments=359 views=535507
# Comentarios en inglés (2020-2023) aceptados: 1
# ChatGPT Tutorial 2025: How to Use ChatGPT - Beginner to Pro! | comments=347 views=514061
# Comentarios en inglés (2020-2023) aceptados: 94
#
#  Query: 'AI risks'
# Vídeos seleccionados: 8 (de 50) tras filtros
# Elon Musk tells Tucker potential dangers of hyper-intelligent AI | comments=9845 views=3510097
# Comentarios en inglés (2020-2023) aceptados: 0
# Tech Expert Warns of AI's Potentially Dangerous Capabilities | comments=3728 views=2361682
# Comentarios en inglés (2020-2023) aceptados: 0
# Trump deepfakes on social media prompt warnings of AI risks | comments=776 views=194151
# Comentarios en inglés (2020-2023) aceptados: 225
# UN Security Council meets for first time on AI risks - BBC News | comments=461 views=208965
# Comentarios en inglés (2020-2023) aceptados: 290
# The Urgent Risks of Runaway AI — and What to Do about Them | Gary Marc | comments=428 views=224443
# Comentarios en inglés (2020-2023) aceptados: 231
#
#  Query: 'AI benefits'
# Vídeos seleccionados: 12 (de 50) tras filtros
# The Future of Artificial Intelligence By Sandeep Maheshwari | Will Cha | comments=6154 views=4134496
# Comentarios en inglés (2020-2023) aceptados: 136
# What is Artificial Intelligence With Full Information? – [Hindi] – Qui | comments=2494 views=3870180
# Comentarios en inglés (2020-2023) aceptados: 94
# How will AI change the world? | comments=1980 views=2230142
# Comentarios en inglés (2020-2023) aceptados: 101
# Is AI the most important technology of the century? | comments=558 views=461242
# Comentarios en inglés (2020-2023) aceptados: 274
# Why I'm not worried about AI ART | comments=557 views=46694
# Comentarios en inglés (2020-2023) aceptados: 238
# How AI Could Empower Any Business | Andrew Ng | TED | comments=513 views=1253018
# Comentarios en inglés (2020-2023) aceptados: 210
#
#  Query: 'AI ethics'
# Vídeos seleccionados: 5 (de 50) tras filtros
# AI is an Ethical Nightmare | comments=4329 views=1179678
# Comentarios en inglés (2020-2023) aceptados: 1
# AI Ethics, Artists, and What You Can Do About It | comments=2155 views=158354
# Comentarios en inglés (2020-2023) aceptados: 280
# AI Ethics Researcher Timnit Gebru's Firing Doesn’t Look Good For Googl | comments=848 views=113097
# Comentarios en inglés (2020-2023) aceptados: 290
# Artificial Intelligence Class 9 Chapter 1 | Ethics of Artificial Intel | comments=464 views=139103
# Comentarios en inglés (2020-2023) aceptados: 64
#
#  Query: 'AI in education'
# Vídeos seleccionados: 7 (de 50) tras filtros
# AI can do your homework. Now what? | comments=3079 views=1548939
# Comentarios en inglés (2020-2023) aceptados: 0
# Should we let students use ChatGPT? | Natasha Berg | TEDxSioux Falls | comments=384 views=423423
# Comentarios en inglés (2020-2023) aceptados: 61
#
#  Query: 'ChatGPT learning tool'
# Vídeos seleccionados: 13 (de 20) tras filtros
# How to use ChatGPT to easily learn any skill you want | comments=2475 views=2049333
# Comentarios en inglés (2020-2023) aceptados: 103
# ChatGPT Tutorial for Beginners in Hindi | Step by Step | comments=1930 views=3201015
# Comentarios en inglés (2020-2023) aceptados: 0
# Prompt Engineering Tutorial – Master ChatGPT and LLM Responses | comments=1108 views=2589191
# Comentarios en inglés (2020-2023) aceptados: 18
# ChatGPT Tutorial - for all College students & Coders | comments=1083 views=2756517
# Comentarios en inglés (2020-2023) aceptados: 226
# Learn ANY language easily with these ChatGPT prompts | comments=985 views=851434
# Comentarios en inglés (2020-2023) aceptados: 146
# How To Use ChatGPT To Learn ANY Skill Quickly (Tutorial) | comments=560 views=1708343
# Comentarios en inglés (2020-2023) aceptados: 202
# How To Learn ANY Language With These ChatGPT Prompts | comments=526 views=530059
# Comentarios en inglés (2020-2023) aceptados: 37
# Learn Anything FASTER With ChatGPT (5 ChatGPT Prompts For Studying) | comments=372 views=529289
# Comentarios en inglés (2020-2023) aceptados: 188
# How to learn anything fast using ChatGPT | Full guide to studying with | comments=271 views=489734
# Comentarios en inglés (2020-2023) aceptados: 133
#
#  Query: 'AI replacing teachers'
# Vídeos seleccionados: 6 (de 50) tras filtros
# A.I. - The END of Language Learning? | comments=978 views=89346
# Comentarios en inglés (2020-2023) aceptados: 153
# Why AI will never replace humans | Alexandr Wang | TEDxBerkeley | comments=711 views=382696
# Comentarios en inglés (2020-2023) aceptados: 136
#
#  Query: 'ChatGPT homework students'
# Vídeos seleccionados: 2 (de 4) tras filtros
# English Teacher Grades Homework By ChatGPT | WIRED | comments=863 views=564055
# Comentarios en inglés (2020-2023) aceptados: 263
#
#  Query: 'artificial intelligence school'
# Vídeos seleccionados: 6 (de 50) tras filtros
# B.Tech in Artificial Intelligence(AI) at IIT Hyderabad | My Degree Exp | comments=295 views=164367
# Comentarios en inglés (2020-2023) aceptados: 101
#
#  Query: 'AI for learning'
# Vídeos seleccionados: 15 (de 50) tras filtros
# AI Learns to Walk (deep reinforcement learning) | comments=10105 views=13088374
# Comentarios en inglés (2020-2023) aceptados: 1
# How to Make Learning as Addictive as Social Media | Duolingo's Luis Vo | comments=5432 views=10557472
# Comentarios en inglés (2020-2023) aceptados: 0
# AI Agent Learns to Escape (deep reinforcement learning) | comments=5405 views=8352904
# Comentarios en inglés (2020-2023) aceptados: 1
# AI Agent Learns to Escape (deep reinforcement learning) | comments=4255 views=4904252
# Comentarios en inglés (2020-2023) aceptados: 1
# AI Learns To Swing Like Spiderman | comments=3062 views=7087707
# Comentarios en inglés (2020-2023) aceptados: 0
# AI Learns to Speedrun Mario | comments=1067 views=1238180
# Comentarios en inglés (2020-2023) aceptados: 0
# AI vs Machine Learning | comments=1012 views=1500508
# Comentarios en inglés (2020-2023) aceptados: 25
# How I'd Learn AI (if I could start over) | comments=975 views=1841369
# Comentarios en inglés (2020-2023) aceptados: 1
# AI Basic Concepts  - ChatGPT | comments=706 views=235868
# Comentarios en inglés (2020-2023) aceptados: 124
# How I'd Learn AI (If I Had to Start Over) | comments=668 views=960217
# Comentarios en inglés (2020-2023) aceptados: 0
#
#  Query: 'AI and jobs future'
# Vídeos seleccionados: 10 (de 50) tras filtros
# A.I. Tries 20 Jobs | WIRED | comments=3627 views=809749
# Comentarios en inglés (2020-2023) aceptados: 64
# All The Jobs AI Will Replace In 5 Years (And Jobs That It Won’t) | comments=1404 views=473660
# Comentarios en inglés (2020-2023) aceptados: 0
# AI/ML Engineer path - The Harsh Truth | comments=686 views=506784
# Comentarios en inglés (2020-2023) aceptados: 117
# How AI Is Already Reshaping White-Collar Work | WSJ | comments=558 views=325354
# Comentarios en inglés (2020-2023) aceptados: 156
# AI Expert Explains Future Programming Jobs… and Python | comments=483 views=306757
# Comentarios en inglés (2020-2023) aceptados: 140
# What jobs are safe from AI? | comments=437 views=112864
# Comentarios en inglés (2020-2023) aceptados: 89
# AI’s Hottest New Job Pays Up to $250K a Year. So I Applied. | WSJ | comments=316 views=438667
# Comentarios en inglés (2020-2023) aceptados: 78
# How Robots Are Taking Our Jobs | Future Human A.I. | comments=263 views=49557
# Comentarios en inglés (2020-2023) aceptados: 115
#
#  Query: 'AI taking jobs'
# Vídeos seleccionados: 5 (de 25) tras filtros
# Will a robot take my job? | The Age of A.I. | comments=4066 views=0
# Comentarios en inglés (2020-2023) aceptados: 278
#
#  Query: 'AI creating jobs'
# Vídeos seleccionados: 11 (de 50) tras filtros
# I Made a Fake AI | comments=11298 views=10274640
# Comentarios en inglés (2020-2023) aceptados: 1
# 10 JOBS That AI Cannot Replace | Artificial Intelligence | Careers | T | comments=751 views=120335
# Comentarios en inglés (2020-2023) aceptados: 247
#
#  Query: 'new jobs artificial intelligence'
# Vídeos seleccionados: 5 (de 50) tras filtros
#
#  Query: 'AI employment'
# Vídeos seleccionados: 9 (de 16) tras filtros
# Top 7 Jobs That AI Will Never Be Able to Replace | Safest Careers for  | comments=328 views=258939
# Comentarios en inglés (2020-2023) aceptados: 6
# How AI is Deciding Who Gets Hired | comments=286 views=186813
# Comentarios en inglés (2020-2023) aceptados: 155
#
#  Query: 'AI unemployment'
# Vídeos seleccionados: 2 (de 50) tras filtros
# Capitalism Doesn't Need Consumers Anymore... | comments=4858 views=1164402
# Comentarios en inglés (2020-2023) aceptados: 1
#
#  Query: 'will AI take my job'
# Vídeos seleccionados: 9 (de 50) tras filtros
# Why AI will NOT be taking Your Animation job | comments=1007 views=128320
# Comentarios en inglés (2020-2023) aceptados: 190
# Will AI take our jobs? | Sam Altman and Lex Fridman | comments=985 views=147424
# Comentarios en inglés (2020-2023) aceptados: 268
# Can artists protect their work from AI? – BBC News | comments=806 views=92631
# Comentarios en inglés (2020-2023) aceptados: 150
# What I Think About AI Taking Your Jobs | comments=511 views=98500
# Comentarios en inglés (2020-2023) aceptados: 288
#
#  Query: 'ChatGPT replace workers'
# Vídeos seleccionados: 2 (de 50) tras filtros
# 3 Jobs Chat GPT Will Fully Replace | comments=802 views=206172
# Comentarios en inglés (2020-2023) aceptados: 263
#
#  Total comentarios recogidos (2020-2023): 9372
#       video_id                  comment_id  \
# 0  vJefOB8kec8  Ugw5fD8RYage0HNS3G54AaABAg
# 1  brQLpTnDwyg  UgybdJnp4QpZsYKYQPp4AaABAg
# 2  uTl8ZYImjBQ  UgyXzwVSolSlJAxqjXh4AaABAg
# 3  uTl8ZYImjBQ  UgybRUKiK4o7WRmwvD54AaABAg
# 4  uTl8ZYImjBQ  Ugw9ci31VKMV-o7aSPZ4AaABAg
#
#                                                 text  likes  \
# 0  🤖 Join my AI Course: https://academy.dhruvrath...   4894
# 1  Play Conflict of Nations for FREE on PC, iOS, ...    564
# 2  Most Musicians: Famous, elegant, but drama fil...      0
# 3                     Love it!\nHugs from Brazil!\n❤      0
# 4  Tom, can you please release a karaoke version ...      0
#
#                    date                   author  reply_count  \
# 0  2023-07-16T15:13:09Z             @dhruvrathee          726
# 1  2023-07-06T21:37:41Z             @TheWhyFiles          190
# 2  2023-12-25T01:46:57Z              @cowbell420            0
# 3  2023-12-24T20:06:55Z  @luandareisoliveira8551            0
# 4  2023-12-09T07:48:57Z         @SeekerofWeird__            0
#
#                                          video_title        channel  \
# 0  The Truth about Artificial Intelligence and Ch...   Dhruv Rathee
# 1  Artificial Intelligence Out of Control: The Ap...  The Why Files
# 2           Artificial Intelligence (Official Video)      Tom Cardy
# 3           Artificial Intelligence (Official Video)      Tom Cardy
# 4           Artificial Intelligence (Official Video)      Tom Cardy
#
#            published_at               query_used  video_viewCount  \
# 0  2023-07-16T15:05:29Z  artificial intelligence         13167228
# 1  2023-07-07T01:00:11Z  artificial intelligence          4815200
# 2  2021-08-05T21:36:52Z  artificial intelligence          2704404
# 3  2021-08-05T21:36:52Z  artificial intelligence          2704404
# 4  2021-08-05T21:36:52Z  artificial intelligence          2704404
#
#    video_commentCount  video_duration_sec
# 0               31503                1357
# 1               19747                2628
# 2                3534                 241
# 3                3534                 241
# 4                3534                 241

# %%
df["date"] = pd.to_datetime(df["date"])
df.groupby("video_id")["date"].agg(["min","max","count"]).sort_values("count", ascending=False).head(10)
# Out:
#                                   min                       max  count
# video_id
# GwG2pQo9eoo 2023-07-18 21:13:03+00:00 2023-11-10 22:23:10+00:00    290
# fWqpPsMXVsI 2020-12-29 00:26:35+00:00 2023-06-17 05:22:00+00:00    290
# A2bbR9ztl6Y 2023-06-19 12:46:24+00:00 2023-12-26 06:22:14+00:00    288
# WY518YRfs5M 2023-03-08 08:44:54+00:00 2023-11-15 04:10:13+00:00    285
# Nn_w3MnCyDY 2022-11-30 08:48:22+00:00 2023-12-30 12:26:44+00:00    280
# f2aocKWrPG8 2022-02-26 22:44:06+00:00 2023-12-26 22:57:44+00:00    278
# -T__YWoq45I 2023-04-04 15:43:20+00:00 2023-11-05 11:44:03+00:00    274
# qof80Sy3__8 2023-03-26 03:35:56+00:00 2023-12-25 23:00:20+00:00    268
# WutWZN8MWHk 2022-12-10 01:09:14+00:00 2023-10-18 22:15:31+00:00    263
# nneN5MyE6d8 2023-02-11 15:30:15+00:00 2023-12-28 18:33:20+00:00    263

# %%
df["date"] = pd.to_datetime(df["date"], utc=True)

span = (df.groupby("video_id")["date"].max() - df.groupby("video_id")["date"].min()).sort_values(ascending=False)
span.head(10)
# Out:
# video_id
# 0yCJMt9Mx9c   1013 days 03:52:53
# fWqpPsMXVsI    900 days 04:55:25
# BjdpKNRVuvY    797 days 15:54:42
# rJ1Qao09CFI    753 days 15:12:26
# 6nGM37ThEsU    685 days 03:50:33
# f2aocKWrPG8    668 days 00:13:38
# q8lJN5oJOss    655 days 07:10:02
# SAUhNWQ0phQ    512 days 23:04:11
# iXCmoQDEoe4    484 days 12:57:03
# reUZRyXxUs4    433 days 16:32:16
# Name: date, dtype: timedelta64[ns]

# %%
n_videos = df["video_id"].nunique()
n_comments = len(df)
print("videos:", n_videos, "| comments:", n_comments, "| avg comments/video:", n_comments / n_videos)
# Out:
# videos: 81 | comments: 9372 | avg comments/video: 115.70370370370371

# %%
n_videos = df["video_id"].nunique()
n_comments = len(df)
top_channels = df["channel"].value_counts().head(10)

print("videos:", n_videos)
print("comments:", n_comments)
print("avg comments/video:", round(n_comments/n_videos, 1))
print("\nTop 10 channels by comments:\n", top_channels)
# Out:
# videos: 81
# comments: 9372
# avg comments/video: 115.7
#
# Top 10 channels by comments:
#  channel
# TED-Ed               607
# TED                  492
# BBC News             440
# Apna College         384
# WIRED                327
# VICE News            290
# The PrimeTime        288
# Forbes               285
# Proko                280
# YouTube Originals    278
# Name: count, dtype: int64

# %%
print("videos:", df["video_id"].nunique())
print("channels:", df["channel"].nunique())
print("comments:", len(df))
# Out:
# videos: 81
# channels: 61
# comments: 9372

# %%
top10_vid_share = df["video_id"].value_counts(normalize=True).head(10).sum()
top10_ch_share = df["channel"].value_counts(normalize=True).head(10).sum()
print("Top10 videos share:", round(top10_vid_share,3))
print("Top10 channels share:", round(top10_ch_share,3))
# Out:
# Top10 videos share: 0.297
# Top10 channels share: 0.392

# %%
df["date"] = pd.to_datetime(df["date"], utc=True)
monthly = df.set_index("date").resample("M").size()
monthly.tail(24)
# Out:
# C:\Users\mbgaz\AppData\Local\Temp\ipykernel_23140\3803432215.py:2: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   monthly = df.set_index("date").resample("M").size()
# date
# 2022-01-31 00:00:00+00:00      16
# 2022-02-28 00:00:00+00:00     135
# 2022-03-31 00:00:00+00:00      32
# 2022-04-30 00:00:00+00:00      14
# 2022-05-31 00:00:00+00:00      29
# 2022-06-30 00:00:00+00:00      47
# 2022-07-31 00:00:00+00:00      83
# 2022-08-31 00:00:00+00:00     157
# 2022-09-30 00:00:00+00:00      46
# 2022-10-31 00:00:00+00:00     129
# 2022-11-30 00:00:00+00:00      50
# 2022-12-31 00:00:00+00:00     211
# 2023-01-31 00:00:00+00:00     282
# 2023-02-28 00:00:00+00:00     241
# 2023-03-31 00:00:00+00:00     648
# 2023-04-30 00:00:00+00:00    1145
# 2023-05-31 00:00:00+00:00     609
# 2023-06-30 00:00:00+00:00    1039
# 2023-07-31 00:00:00+00:00     792
# 2023-08-31 00:00:00+00:00     457
# 2023-09-30 00:00:00+00:00     519
# 2023-10-31 00:00:00+00:00     373
# 2023-11-30 00:00:00+00:00     770
# 2023-12-31 00:00:00+00:00    1010
# Freq: ME, dtype: int64

# %%
df["date"] = pd.to_datetime(df["date"], utc=True)
df.groupby(df["date"].dt.year).size()
# Out:
# date
# 2020     191
# 2021     347
# 2022     949
# 2023    7885
# dtype: int64
